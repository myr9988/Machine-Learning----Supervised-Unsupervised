# %% [markdown]
# CASE-
#
# Consider there is submarine & there is War going on between 2 countries, ENEMY planted some mines(explosives) in the ocean & there are rocks also present in the ocean. Submarine needs to predict whether it is crossing mine or rock.
# Our job is to make a system that can predict whether the object beneath submarine is a mine or rock.
# Submarine sends sound signals, then the signal data will be processed & will be detected whether it is mine or rock.

# %% [markdown]
# WORK FLOW-
#
# COLLECT THE DATA
#
# DATA PRE PROCESSING
#
# TRAIN TEST SPLIT
#
# LOGISTIC REGRESSION MODEL-ITS A BINARY CLASSIFICATION PROBLEM
#
# TRAINED LOGISTIC REGRESSION MODEL
#
# PREDICTION

# %%
# Importing necessary libraries

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Importing data

sonar = pd.read_csv(r'C:\Users\SHREE\Downloads\Python CODES\SONAR Rock VS Mine Prediction\sonar data.csv', header = None)
sonar.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %% [markdown]
# Data preprocessing

# %%
# no of rows & columns

sonar.shape
# Out:
# (208, 61)

# %%
# Stastitical description of data

sonar.describe().T
# Out:
#     count      mean       std     min       25%      50%       75%     max
# 0   208.0  0.029164  0.022991  0.0015  0.013350  0.02280  0.035550  0.1371
# 1   208.0  0.038437  0.032960  0.0006  0.016450  0.03080  0.047950  0.2339
# 2   208.0  0.043832  0.038428  0.0015  0.018950  0.03430  0.057950  0.3059
# 3   208.0  0.053892  0.046528  0.0058  0.024375  0.04405  0.064500  0.4264
# 4   208.0  0.075202  0.055552  0.0067  0.038050  0.06250  0.100275  0.4010
# 5   208.0  0.104570  0.059105  0.0102  0.067025  0.09215  0.134125  0.3823
# 6   208.0  0.121747  0.061788  0.0033  0.080900  0.10695  0.154000  0.3729
# 7   208.0  0.134799  0.085152  0.0055  0.080425  0.11210  0.169600  0.4590
# 8   208.0  0.178003  0.118387  0.0075  0.097025  0.15225  0.233425  0.6828
# 9   208.0  0.208259  0.134416  0.0113  0.111275  0.18240  0.268700  0.7106
# 10  208.0  0.236013  0.132705  0.0289  0.129250  0.22480  0.301650  0.7342
# ...

# %%
# Count of categorical variable

sonar[60].value_counts()
# Out:
# M    111
# R     97
# Name: 60, dtype: int64

# %% [markdown]
# M-->Mine
#
# R-->Rock

# %%
# More the data, more the accurate model will.

# %%
sonar.groupby(60).mean()
# Out:
#           0         1         2         3         4         5         6   \
# 60
# M   0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R   0.022498  0.030303  0.035951  0.041447  0.062028  0.096224  0.114180
#
#           7         8         9   ...        50        51        52        53  \
# 60                                ...
# M   0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R   0.117596  0.137392  0.159325  ...  0.012311  0.010453  0.009640  0.009518
#
#           54        55        56        57        58        59
# 60
# M   0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R   0.008567  0.007430  0.007814  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %%
# we got mean values for all the columns, there is quiet a difference between mine & rock values,
# using this we are going to predict what is the object

# %%
# Splitting data & labels

x= sonar.drop(columns=60,axis=1)
y=sonar[60]

# %%
print(x)
print(y)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %% [markdown]
# Splitting the data into train & test

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, stratify=y, random_state=1)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (208, 60) (187, 60) (21, 60)

# %% [markdown]
# Model Training --> Logistic Regression

# %%
model = LogisticRegression()

# %%
# Training the logistic regression model with training data

model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
# Accuracy on training data

x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction,y_train)

# %%
print('Accuracy on training data :', training_data_accuracy)
# Out:
# Accuracy on training data : 0.8342245989304813

# %%
# Accuracy on test data

x_test_prediction = model.predict(x_test)
testing_data_accuracy = accuracy_score(x_test_prediction,y_test)

# %%
print('Accuracy on testing data :', testing_data_accuracy)
# Out:
# Accuracy on testing data : 0.7619047619047619

# %%
# Accuracy score of our model is good so our model should be considered for prediction

# %% [markdown]
# Making a Predictive System

# %%
input_data = (0.0207,0.0535,0.0334,0.0818,0.0740,0.0324,0.0918,0.1070,0.1553,0.1234,0.1796,0.1787,0.1247,0.2577,0.3370,0.3990,0.1647,0.2266,0.3219,0.5356,0.8159,1.0000,0.8701,0.6889,0.6299,0.5738,0.5707,0.5976,0.4301,0.2058,0.1000,0.2247,0.2308,0.3977,0.3317,0.1726,0.1429,0.2168,0.1967,0.2140,0.3674,0.2023,0.0778,0.0925,0.2388,0.3400,0.2594,0.1102,0.0911,0.0462,0.0171,0.0033,0.0050,0.0190,0.0103,0.0121,0.0042,0.0090,0.0070,0.0099)

# Changing input data to numpy array

input_data_as_numpy_array = np.asarray(input_data)

# We need to reshape the numpy array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 'R'):
    print('The object is a Rock')
else:
    print('The object is a Mine')
# Out:
# ['M']
# The object is a Mine
